# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakinat-Folorunso/CMP701-Computer-Programming-I-PYTHON-/blob/main/Labs/CMP701_Mini_Project_Student_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CMP701: Computer Programming I
# ## Mini Project – Student Workbook (Google Colab)
#
# **Programme:** PGD Computer Science
# **Course:** CMP701 – Computer Programming I
# **Platform:** Google Colab (Python 3)
#
# **Lecturer:**
# **Dr. Sakinat Folorunso**
# Associate Professor of AI Systems
# Department of Computer Sciences
# Olabisi Onabanjo University, Ago-Iwoye
# 📧 sakinat.folorunso@oouagoiwoye.edu.ng
#
# ---
#
# ## 🧾 STUDENT INFORMATION (Fill This Section)
#
# ```python
# # Name:
# # Matric Number:
# # Programme: PGD Computer Science
# # Course: CMP701 – Computer Programming I
# ```

# %% [markdown]
# ## 🎯 Mini-Project Objective
#
# This mini-project tests your ability to:
# - Apply Python programming concepts learned in CMP701
# - Solve a real-world problem logically
# - Write modular, readable, and well-documented code
# - Use files for persistent storage
#
# You are expected to **design, implement, and explain** your solution.

# %% [markdown]
# ## 🧠 Project Options (Choose ONE)
#
# ### OPTION A (Recommended): Student Result Management System
# Your program should:
# 1. Accept student name
# 2. Accept scores for **at least 3 courses**
# 3. Compute total and average score
# 4. Determine grade using decision statements
# 5. Save result to a file
# 6. Read and display saved results
#
# ---
#
# ### OPTION B: Simple Payroll System
# Your program should:
# 1. Accept employee name and basic salary
# 2. Compute allowances and deductions
# 3. Calculate net salary
# 4. Save payroll record to file
# 5. Display payroll summary
#
# ---
#
# ### OPTION C: Course Registration & Attendance System
# Your program should:
# 1. Register student and courses
# 2. Track attendance using lists/dictionaries
# 3. Save attendance record to file
# 4. Display attendance summary

# %% [markdown]
# ## 🧱 Mandatory Programming Requirements (VERY IMPORTANT)
#
# Your solution MUST include:
# - input() and print()
# - if / elif / else
# - for or while loop
# - Lists AND dictionaries
# - At least **4 user-defined functions**
# - Strings (names, formatting)
# - File handling (read and write)
# - Clear comments explaining your code
#
# ⚠️ Missing any requirement attracts marks deduction.

# %% [markdown]
# ## 🧩 Recommended Program Structure
#
# You are encouraged to structure your program as follows:
#
# ```text
# 1. input_data()
# 2. compute_result()
# 3. determine_grade()
# 4. save_to_file()
# 5. read_from_file()
# 6. display_output()
# ```

# %% [markdown]
# ## ✏️ STEP 1: Define Your Functions
#
# 👉 Write functions for:
# - Collecting input
# - Processing data
# - Determining result/grade

# %%
# TODO: Write a function to collect input data
def input_data():
    pass  # replace pass with your code

# %%
# TODO: Write a function to compute average or salary
def compute_result(data):
    pass

# %%
# TODO: Write a function to determine grade or category
def determine_grade_or_status(value):
    pass

# %% [markdown]
# ## ✏️ STEP 2: File Handling Functions

# %%
# TODO: Write a function to save records to a file
def save_to_file(record):
    pass

# %%
# TODO: Write a function to read and display records
def read_from_file():
    pass

# %% [markdown]
# ## ✏️ STEP 3: Main Program Logic

# %%
# TODO: Call your functions here and control program flow
def main():
    pass

# Run the program
main()

# %% [markdown]
# ## 🧪 Testing Checklist (Before Submission)
#
# ✔ Program runs without errors
# ✔ All required concepts are used
# ✔ Records are saved to file
# ✔ Output is clearly displayed
# ✔ Code is properly commented

# %% [markdown]
# ## 📝 Submission Instructions
#
# - Submit this notebook (.ipynb) on the course platform
# - Ensure your name and matric number are clearly written
# - Do NOT submit screenshots
# - Late submission attracts penalty
#
# ---
#
# ### ✅ END OF MINI PROJECT
# Good luck!
