# %% [markdown]
# <a href="https://colab.research.google.com/github/Sakinat-Folorunso/CMP701-Computer-Programming-I-PYTHON-/blob/main/Labs/CMP701_Week01_Introduction_to_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CMP701: Computer Programming I
# ## Week 01 – Introduction to Computer Programming (Google Colab)
#
# **Programme:** PGD Computer Science
# **Course Unit:** 3 (LH: 30; PH: 45)
# **Platform:** Google Colab (Python 3)
#
# **Prepared by:**
# **Dr. Sakinat Folorunso**
# Associate Professor of AI Systems
# Department of Computer Sciences
# Olabisi Onabanjo University, Ago-Iwoye, Nigeria
# sakinat.folorunso@oouagoiwoye.edu.ng
#
# ---
#
# ### 🎯 Learning Objectives
# By the end of this lab, students should be able to:
# - Navigate and use Google Colab effectively
# - Understand what computer programming means
# - Write and execute simple Python programs
# - Use the `print()` function confidently
# - Modify and run code independently

# %% [markdown]
# ## Short Concept Recap (From Lecture)
# Computer programming is the process of giving **step-by-step instructions** to a computer to solve problems.
#
# Python is chosen for this course because:
# - It is easy to read and write
# - It is widely used in AI and data science
# - It allows beginners to focus on **problem solving**, not syntax
#
# In this lab, we focus on **output programs**.

# %% [markdown]
# ## 🧪 Lab 1.1: Your First Python Program
# The traditional first program in any programming language is **Hello, World**.

# %%
# This line displays a message on the screen
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### 🔍 Explanation
# - `print()` is a built-in Python function
# - Anything inside quotation marks is treated as **text (string)**
# - When you run the cell, Python displays the text

# %% [markdown]
# ## 🧪 Lab 1.2: Printing Multiple Lines
# You can print multiple messages using multiple `print()` statements.

# %%
# Printing multiple lines of text
print("Welcome to CMP701")
print("Computer Programming I")
print("PGD Computer Science")
# Out:
# Welcome to CMP701
# Computer Programming I
# PGD Computer Science

# %% [markdown]
# ## 🧪 Lab 1.3: Printing Personal Information
# Let us print personal information.

# %%
# Printing personal details
print("Name: _________________")
print("Department: Computer Science")
print("Programme: PGD Computer Science")
# Out:
# Name: ____________________
# Department: Computer Science
# Programme: PGD Computer Science

# %% [markdown]
# ## ✏️ Guided Practice (Student Task)
# Modify the code above to:
# 1. Replace the blank with **your full name**
# 2. Add your **state of origin**
# 3. Add today's date

# %% [markdown]
# ## ⚠️ Common Beginner Mistakes
# - Forgetting quotation marks around text
# - Writing `Print` instead of `print`
# - Forgetting to run the cell
#
# 👉 Python is **case-sensitive**

# %% [markdown]
# ## 📝 Class Task
# 1. Write a Python program that prints:
#    - Your name
#    - Your matric number
#    - Your favourite course
# 2. Run the program and confirm the output.

# %% [markdown]
# ## 🏠 Assignment (To Be Submitted)
# Write a Python program that prints **five real-life problems** that can be solved using computer programs.
#
# Example:
# - ATM transactions
# - Online registration systems
#
# 👉 Each problem should appear on a **separate line**.

# %% [markdown]
# ## 🔎 Reflection Question
# In your own words:
# - What do you think programming means?
# - Why do you think Python is suitable for beginners?

# %% [markdown]
# ---
# ### ✅ End of Week 01 Lab
# Proceed to **Week 02 – Problem Solving and Algorithms** after confirmation.
